# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.0/984.0 kB 61.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 78.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 75.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 57.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 78.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO


model = YOLO('yolov8s.pt')  # Load the lightweight model

# Train model
model.train(data='/content/drive/MyDrive/data_try_2/data.yaml', epochs=50, imgsz=640, batch=16, device='cuda')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 21.5M/21.5M [00:00<00:00, 42.0MB/s]
# Ultralytics 8.3.116 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
metrics = model.val()
# Out:
# Ultralytics 8.3.116 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 11,126,745 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 10.3±22.3 ms, read: 48.1±29.5 MB/s, size: 285.3 KB)
# val: Scanning /content/drive/MyDrive/data_try_2/labels/val.cache... 120 images, 0 backgrounds, 0 corrupt: 100%|██████████| 120/120 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:03<00:00,  2.04it/s]
#                    all        120        123      0.996      0.976      0.983      0.956
#              groundnut         40         40      0.992      0.975      0.983      0.952
#               longWeed         46         48          1      0.952      0.971       0.93
#              shortWeed         35         35      0.995          1      0.995      0.986
# Speed: 5.3ms preprocess, 7.6ms inference, 0.0ms loss, 2.6ms postprocess per image
# ...

# %%
import shutil
shutil.copy("runs/detect/train/weights/best.pt", "/content/drive/MyDrive/model_data_try_2_yolov8s/yolo_best.pt")
# Out:
# '/content/drive/MyDrive/model_data_try_2_yolov8s/yolo_best.pt'

# %%
shutil.copy("runs/detect/train/weights/last.pt", "/content/drive/MyDrive/model_data_try_2_yolov8s/yolo_last.pt")
# Out:
# '/content/drive/MyDrive/model_data_try_2_yolov8s/yolo_last.pt'

# %%
results = model('/content/t1.webp')

# Display results
results[0].show()

# Save results properly
results[0].save(filename='/content/drive/MyDrive/results/result1.jpg')  # Ensure a valid filename
# Out:
# image 1/1 /content/t1.webp: 416x640 1 longWeed, 38.0ms
# Speed: 3.5ms preprocess, 38.0ms inference, 2.4ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=463x280>
# '/content/drive/MyDrive/results/result1.jpg'

# %%
results = model('/content/drive/MyDrive/data_try_2/images/train/DSC02354.JPG')

# Access the first result in the list
results[0].show()  # Show output
results[0].save(filename='/content/drive/MyDrive/results/result00.jpg')  # Ensure a valid filename
# Out:
# image 1/1 /content/drive/MyDrive/data_try_2/images/train/DSC02354.JPG: 480x640 1 groundnut, 8.3ms
# Speed: 4.4ms preprocess, 8.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=1200x900>
# '/content/drive/MyDrive/results/result00.jpg'

# %%
results = model('/content/drive/MyDrive/data_try_2/images/train/DSC09388.jpg')

# Access the first result in the list
results[0].show()  # Show output
results[0].save(filename='/content/drive/MyDrive/results/result00.jpg')  # Ensure a valid filename
# Out:
# image 1/1 /content/drive/MyDrive/data_try_2/images/train/DSC09388.jpg: 480x640 1 longWeed, 7.1ms
# Speed: 2.9ms preprocess, 7.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=1200x900>
# '/content/drive/MyDrive/results/result00.jpg'

# %%
results = model('/content/ty.jpeg')

# Display results
results[0].show()

# Save results properly
results[0].save(filename='/content/drive/MyDrive/results/result1.jpg')  # Ensure a valid filename
# Out:
# image 1/1 /content/ty.jpeg: 480x640 1 groundnut, 10.8ms
# Speed: 3.9ms preprocess, 10.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
# <PIL.Image.Image image mode=RGB size=480x360>
# '/content/drive/MyDrive/results/result1.jpg'
